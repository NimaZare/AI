# %% [markdown]
# <a href="https://colab.research.google.com/github/NimaZare/AI/blob/main/aiolearn_j2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt
import cv2

# %%
image = cv2.imread("anisa.jpg")

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
model = cv2.CascadeClassifier("model.xml")

# %%
face = model.detectMultiScale(image)

# %%
image = cv2.rectangle(image, (100, 100), (200, 200), (0,255,0), 3)

# %%
x = face[0][0]
y = face[0][1]
a = face[0][2]
b = face[0][3]

# %%
image = cv2.rectangle(image, (x, y), (x+a, y+b), (0,255,0), 3)

# %%
plt.imshow(image)

# %% [markdown]
# # **Original App**

# %%
from matplotlib import pyplot as plt
import cv2

# %%
image = cv2.imread("anisa.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
model = cv2.CascadeClassifier("model.xml")

face = model.detectMultiScale(image)

x = face[0][0]
y = face[0][1]
a = face[0][2]
b = face[0][3]

image = cv2.rectangle(image, (x, y), (x+a, y+b), (0,255,0), 4)

plt.imshow(image)
